# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/USER/Desktop/Knowledge Distillaation/1 Datasets/Compiled Datasets/STS_TL_400k.csv")

# %%
df
# Out:
#                                                        s1  \
# 0       "Hindi ko ugali ang mamulitika; mas gusto kong...
# 1       Ayon naman kay Bayan Muna Rep. Carlos Zarate, ...
# 2       Ayon naman sa Philippine Embassy sa Washington...
# 3       Paano maipagtatanggol ng mga ordinaryong mamam...
# 4                                           SM by the bay
# ...                                                   ...
# 419995     2p.m. Arellano University vs Hog's Breath Cafe
# 419996  Jason Davee: We rather want the senate head to...
# 419997  Ipinatupad ang liquid ban sa mga istasyon ng M...
# 419998  Team Standings: zArellano (13-4); zSan Beda (1...
# 419999  Batay sa nakalap na report mula sa tanggapan n...
#
#                                                        s2  label
# 0       Ito ang dineklara ni Atty. Romulo Macalintal, ...      1
# 1       Dating itinutulak ni Duterte ang pagbabago ng ...      0
# 2       Ayon sa NBI, hindi umano siyento por siyentong...      1
# ...

# %%
#new_df = df.sample(n=100000)

# %%
import numpy as np
df_split = np.array_split(df, 20)

# %%
df_split
# Out:
# [                                                      s1  \
#  0      "Hindi ko ugali ang mamulitika; mas gusto kong...
#  1      Ayon naman kay Bayan Muna Rep. Carlos Zarate, ...
#  2      Ayon naman sa Philippine Embassy sa Washington...
#  3      Paano maipagtatanggol ng mga ordinaryong mamam...
#  4                                          SM by the bay
#  ...                                                  ...
#  20995  Muling hinamon ng Pangulo si Callamard na pumu...
#  20996  Tataas ang presyo ng gasolina, habang magro-ro...
#  20997  Ang ipamamahaging lupa ay nasa Atimonan, Calau...
#  20998  Ikinuwento ng Pangulo na mayroong hinuli na na...
#  20999  Samantala, bahagya lamang ang ikinalaki ng liv...
#
#                                                        s2  label
#  0      Ito ang dineklara ni Atty. Romulo Macalintal, ...      1
#  1      Dating itinutulak ni Duterte ang pagbabago ng ...      0
#  2      Ayon sa NBI, hindi umano siyento por siyentong...      1
# ...

# %%
df_split[0]
# Out:
#                                                       s1  \
# 0      "Hindi ko ugali ang mamulitika; mas gusto kong...
# 1      Ayon naman kay Bayan Muna Rep. Carlos Zarate, ...
# 2      Ayon naman sa Philippine Embassy sa Washington...
# 3      Paano maipagtatanggol ng mga ordinaryong mamam...
# 4                                          SM by the bay
# ...                                                  ...
# 20995  Muling hinamon ng Pangulo si Callamard na pumu...
# 20996  Tataas ang presyo ng gasolina, habang magro-ro...
# 20997  Ang ipamamahaging lupa ay nasa Atimonan, Calau...
# 20998  Ikinuwento ng Pangulo na mayroong hinuli na na...
# 20999  Samantala, bahagya lamang ang ikinalaki ng liv...
#
#                                                       s2  label
# 0      Ito ang dineklara ni Atty. Romulo Macalintal, ...      1
# 1      Dating itinutulak ni Duterte ang pagbabago ng ...      0
# 2      Ayon sa NBI, hindi umano siyento por siyentong...      1
# ...

# %%
#new_df

# %%
#new_df.to_csv('C:/Users/USER/Desktop/Knowledge Distillaation/1 Datasets/Compiled Datasets/STS_TL_100k.csv')

# %%
path = "C:/Users/USER/Desktop/Knowledge Distillaation/1 Datasets/Compiled Datasets/in chunks/"

for i in range(len(df_split)):
      print(df_split[i])
      filename = "STS_TL_chunk" + str(i)
      df_split[i].to_csv(path + str(filename)+ ".csv")
# Out:
#                                                       s1  \
# 0      "Hindi ko ugali ang mamulitika; mas gusto kong...
# 1      Ayon naman kay Bayan Muna Rep. Carlos Zarate, ...
# 2      Ayon naman sa Philippine Embassy sa Washington...
# 3      Paano maipagtatanggol ng mga ordinaryong mamam...
# 4                                          SM by the bay
# ...                                                  ...
# 20995  Muling hinamon ng Pangulo si Callamard na pumu...
# 20996  Tataas ang presyo ng gasolina, habang magro-ro...
# 20997  Ang ipamamahaging lupa ay nasa Atimonan, Calau...
# 20998  Ikinuwento ng Pangulo na mayroong hinuli na na...
# 20999  Samantala, bahagya lamang ang ikinalaki ng liv...
#
#                                                       s2  label
# 0      Ito ang dineklara ni Atty. Romulo Macalintal, ...      1
# 1      Dating itinutulak ni Duterte ang pagbabago ng ...      0
# 2      Ayon sa NBI, hindi umano siyento por siyentong...      1
# ...
